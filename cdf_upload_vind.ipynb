# %% [markdown]
# ### Connect to Cognite with OIDC
#
# CDF UI:
# - https://hafslundeco.fusion.cognite.com/
# - heco-dev
#
# Cognite Python SDK:
# - https://cognite-docs.readthedocs-hosted.com/projects/cognite-sdk-python/en/latest/
# - `pip install cognite-sdk msal`

# %%
import os
import pandas as pd
import numpy as np

from datetime import datetime
from msal import PublicClientApplication

from cognite.client import CogniteClient
from cognite.client.data_classes import TimeSeries, Asset

# %%
# Log-in detaljer
TENANT_ID = str(os.getenv("AZURE_TENANT_ID")) # Disse må endres til string ved å sette
CLIENT_ID = str(os.getenv("AZURE_CLIENT_ID")) # str() rundt, ellers kræsjer neste blokk
CDF_CLUSTER = "az-power-no-northeurope"
COGNITE_PROJECT = "heco-dev"

# %%
# Code to log-in WIHTOUT client_secret
SCOPES = [f"https://{CDF_CLUSTER}.cognitedata.com/.default"]

AUTHORITY_HOST_URI = "https://login.microsoftonline.com"
AUTHORITY_URI = AUTHORITY_HOST_URI + "/" + TENANT_ID
PORT = 53000


def authenticate_azure():

    app = PublicClientApplication(client_id=CLIENT_ID, authority=AUTHORITY_URI)

    # interactive login - make sure you have http://localhost:port in Redirect URI in App Registration as type "Mobile and desktop applications"
    creds = app.acquire_token_interactive(scopes=SCOPES, port=PORT)
    return creds


creds = authenticate_azure()

client = CogniteClient(
    token_url=creds["id_token_claims"]["iss"],
    token=creds["access_token"],
    token_client_id=creds["id_token_claims"]["aud"],
    project=COGNITE_PROJECT,
    base_url=f"https://{CDF_CLUSTER}.cognitedata.com",
    client_name="cognite-python-dev",
)

print(client.iam.token.inspect())
# Out:
# {
#     "subject": "-sTDaBmpTYrnewchD-RUzELOvmjGCp2kx7imzOOWmTg",
#     "projects": [
#         {
#             "url_name": "heco-dev",
#             "groups": [
#                 2296494088654948,
#                 3141301975681982,
#                 5972473111747815
#             ]
#         }
#     ],
#     "capabilities": [
#         {
#             "assetsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "782671167763856",
#                             "788450409833218",
#                             "1020945958129838",
#                             "1349361264490416",
#                             "1612776730017397",
#                             "1743179964318084",
#                             "2237225820987525",
#                             "3065916339847684",
#                             "4509487486068549",
#                             "5024110628382947",
#                             "5396953645529222",
#                             "5469120571593626",
#                             "6197963466045550",
#                             "6579385575865925",
#                             "7284168543332310",
#                             "7674038780245037",
#                             "8103263546423617"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "datasetsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "idScope": {
#                         "ids": [
#                             "782671167763856",
#                             "788450409833218",
#                             "1020945958129838",
#                             "1349361264490416",
#                             "1612776730017397",
#                             "1743179964318084",
#                             "2237225820987525",
#                             "3065916339847684",
#                             "4509487486068549",
#                             "5024110628382947",
#                             "5396953645529222",
#                             "5469120571593626",
#                             "6197963466045550",
#                             "6579385575865925",
#                             "7284168543332310",
#                             "7674038780245037",
#                             "8103263546423617"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "entitymatchingAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "eventsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "782671167763856",
#                             "788450409833218",
#                             "1020945958129838",
#                             "1349361264490416",
#                             "1612776730017397",
#                             "1743179964318084",
#                             "2237225820987525",
#                             "3065916339847684",
#                             "4509487486068549",
#                             "5024110628382947",
#                             "5396953645529222",
#                             "5469120571593626",
#                             "6197963466045550",
#                             "6579385575865925",
#                             "7284168543332310",
#                             "7674038780245037",
#                             "8103263546423617"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "extractionPipelinesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "782671167763856",
#                             "788450409833218",
#                             "1020945958129838",
#                             "1349361264490416",
#                             "1612776730017397",
#                             "1743179964318084",
#                             "2237225820987525",
#                             "3065916339847684",
#                             "4509487486068549",
#                             "5024110628382947",
#                             "5396953645529222",
#                             "5469120571593626",
#                             "6197963466045550",
#                             "6579385575865925",
#                             "7284168543332310",
#                             "7674038780245037",
#                             "8103263546423617"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "extractionRunsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "782671167763856",
#                             "788450409833218",
#                             "1020945958129838",
#                             "1349361264490416",
#                             "1612776730017397",
#                             "1743179964318084",
#                             "2237225820987525",
#                             "3065916339847684",
#                             "4509487486068549",
#                             "5024110628382947",
#                             "5396953645529222",
#                             "5469120571593626",
#                             "6197963466045550",
#                             "6579385575865925",
#                             "7284168543332310",
#                             "7674038780245037",
#                             "8103263546423617"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "filesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "782671167763856",
#                             "788450409833218",
#                             "1020945958129838",
#                             "1349361264490416",
#                             "1612776730017397",
#                             "1743179964318084",
#                             "2237225820987525",
#                             "3065916339847684",
#                             "4509487486068549",
#                             "5024110628382947",
#                             "5396953645529222",
#                             "5469120571593626",
#                             "6197963466045550",
#                             "6579385575865925",
#                             "7284168543332310",
#                             "7674038780245037",
#                             "8103263546423617"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "functionsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "groupsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "currentuserscope": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "labelsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "782671167763856",
#                             "788450409833218",
#                             "1020945958129838",
#                             "1349361264490416",
#                             "1612776730017397",
#                             "1743179964318084",
#                             "2237225820987525",
#                             "3065916339847684",
#                             "4509487486068549",
#                             "5024110628382947",
#                             "5396953645529222",
#                             "5469120571593626",
#                             "6197963466045550",
#                             "6579385575865925",
#                             "7284168543332310",
#                             "7674038780245037",
#                             "8103263546423617"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "projectsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "rawAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "LIST"
#                 ],
#                 "scope": {
#                     "tableScope": {
#                         "dbsToTables": {
#                             "uc:allprojects:rawdb:state": {},
#                             "uc:005:trading:rawdb": {},
#                             "src:003:fdm:rawdb:state": {},
#                             "cons:allprojects:rawdb": {},
#                             "uc:006:ml_test:rawdb:state": {},
#                             "cons:allprojects:rawdb:state": {},
#                             "uc:001:shop:rawdb:state": {},
#                             "uc:004:inflow:rawdb:state": {},
#                             "uc:002:sandbox:rawdb": {},
#                             "src:005:trading:mult:rawdb": {},
#                             "cons:001:main:rawdb": {},
#                             "src:002:shop:rawdb:state": {},
#                             "uc:001:shop:rawdb": {},
#                             "src:004:licenses:rawdb": {},
#                             "src:005:trading:mult:rawdb:state": {},
#                             "allprojects:rawdb": {},
#                             "src:001:smg:rawdb": {},
#                             "uc:007:dm_test:rawdb": {},
#                             "uc:007:dm_test:rawdb:state": {},
#                             "uc:006:ml_test:rawdb": {},
#                             "src:003:fdm:rawdb": {},
#                             "uc:003:nes:rawdb:state": {},
#                             "src:001:smg:rawdb:state": {},
#                             "uc:003:nes:rawdb": {},
#                             "src:004:licenses:rawdb:state": {},
#                             "uc:004:inflow:rawdb": {},
#                             "src:allprojects:rawdb:state": {},
#                             "uc:allprojects:rawdb": {},
#                             "uc:005:trading:rawdb:state": {},
#                             "cons:001:main:rawdb:state": {},
#                             "uc:002:sandbox:rawdb:state": {},
#                             "allprojects:rawdb:state": {},
#                             "src:002:shop:rawdb": {},
#                             "src:allprojects:rawdb": {}
#                         }
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "relationshipsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "782671167763856",
#                             "788450409833218",
#                             "1020945958129838",
#                             "1349361264490416",
#                             "1612776730017397",
#                             "1743179964318084",
#                             "2237225820987525",
#                             "3065916339847684",
#                             "4509487486068549",
#                             "5024110628382947",
#                             "5396953645529222",
#                             "5469120571593626",
#                             "6197963466045550",
#                             "6579385575865925",
#                             "7284168543332310",
#                             "7674038780245037",
#                             "8103263546423617"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "sequencesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "782671167763856",
#                             "788450409833218",
#                             "1020945958129838",
#                             "1349361264490416",
#                             "1612776730017397",
#                             "1743179964318084",
#                             "2237225820987525",
#                             "3065916339847684",
#                             "4509487486068549",
#                             "5024110628382947",
#                             "5396953645529222",
#                             "5469120571593626",
#                             "6197963466045550",
#                             "6579385575865925",
#                             "7284168543332310",
#                             "7674038780245037",
#                             "8103263546423617"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "sessionsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "timeSeriesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "782671167763856",
#                             "788450409833218",
#                             "1020945958129838",
#                             "1349361264490416",
#                             "1612776730017397",
#                             "1743179964318084",
#                             "2237225820987525",
#                             "3065916339847684",
#                             "4509487486068549",
#                             "5024110628382947",
#                             "5396953645529222",
#                             "5469120571593626",
#                             "6197963466045550",
#                             "6579385575865925",
#                             "7284168543332310",
#                             "7674038780245037",
#                             "8103263546423617"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "transformationsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "typesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "assetsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "1349361264490416"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "datasetsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "idScope": {
#                         "ids": [
#                             "1349361264490416"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "entitymatchingAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "eventsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "1349361264490416"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "extractionPipelinesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "1349361264490416"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "extractionRunsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "1349361264490416"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "filesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "1349361264490416"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "functionsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "groupsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "currentuserscope": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "labelsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "1349361264490416"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "projectsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "rawAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "LIST"
#                 ],
#                 "scope": {
#                     "tableScope": {
#                         "dbsToTables": {
#                             "uc:004:inflow:rawdb:state": {},
#                             "uc:004:inflow:rawdb": {}
#                         }
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "relationshipsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "1349361264490416"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "sequencesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "1349361264490416"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "sessionsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "timeSeriesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "1349361264490416"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "transformationsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "typesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "assetsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "788450409833218"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "datasetsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE",
#                     "OWNER"
#                 ],
#                 "scope": {
#                     "idScope": {
#                         "ids": [
#                             "788450409833218"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "entitymatchingAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "eventsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "788450409833218"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "extractionPipelinesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "788450409833218"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "extractionRunsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "788450409833218"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "filesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "788450409833218"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "functionsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "groupsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "currentuserscope": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "labelsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "788450409833218"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "projectsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "rawAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE",
#                     "LIST"
#                 ],
#                 "scope": {
#                     "tableScope": {
#                         "dbsToTables": {
#                             "uc:006:ml_test:rawdb:state": {},
#                             "uc:006:ml_test:rawdb": {}
#                         }
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "relationshipsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "788450409833218"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "sequencesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "788450409833218"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "sessionsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "LIST",
#                     "CREATE"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "timeSeriesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             "788450409833218"
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "transformationsAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         },
#         {
#             "typesAcl": {
#                 "version": 1,
#                 "actions": [
#                     "READ",
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "heco-dev"
#                 ]
#             }
#         }
#     ]
# }

# %%
client.time_series.list(limit=1)
# Out:
# TimeSeriesList([<cognite.client.data_classes.time_series.TimeSeries at 0x26078e9db50>])

# %% [markdown]
# ### Generelle tips
# - Sjekk at du er i riktig prosjekt: `heco-dev`
# - Sjekk at du bruker riktig datasett: `uc:006:ml_test`
# - Sjekk datamodell / assethierarki i GUI
#     - Den store fordelen med CDF er at du koble sammen forskjellige datakilder og kontekstualisere dem, dvs. sette dem i sammenheng
# - Husk å konvertere alle tidsstempler til UTC

# %% [markdown]
# ### Playaround
# - Create a new asset
# - Create a new timeseries
# - Write to timeseries
# - Read data from timeseries

# %%
# Create an asset
asset_name = "NO1_test2"
client.assets.create([Asset(
    external_id=asset_name,
    name=asset_name,
    data_set_id=client.data_sets.retrieve(external_id="uc:006:ml_test").id,
)])
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x28bc7899e80>])

# %%
# Delete an asset
asset_name = "NO1_test2"
client.assets.delete(
    external_id=asset_name,
)

# %%
# Create a new timeseries connected to asset `NO1`
forecast_date = datetime(2022, 5, 20, 12, 0, 0, 0).replace(microsecond=0)
name = f"NO1_generation_test_series_2{forecast_date}"

client.time_series.create(
    time_series=TimeSeries(
        external_id=name,
        asset_id=client.assets.retrieve(external_id="NO1_test2").id,
        name=name,
        unit="MWh/h",
        data_set_id=client.data_sets.retrieve(external_id="uc:006:ml_test").id
    )
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>id</th>
#       <td>4876105227349445</td>
#     </tr>
#     <tr>
#       <th>external_id</th>
#       <td>NO1_generation_test_series_22022-05-20 12:00:00</td>
#     </tr>
#     <tr>
#       <th>name</th>
#       <td>NO1_generation_test_series_22022-05-20 12:00:00</td>
#     </tr>
#     <tr>
#       <th>is_string</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <td>MWh/h</td>
#     </tr>
#     <tr>
#       <th>asset_id</th>
#       <td>8330732854232942</td>
#     </tr>
#     <tr>
#       <th>is_step</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>security_categories</th>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>data_set_id</th>
#       <td>788450409833218</td>
#     </tr>
#     <tr>
#       <th>created_time</th>
#       <td>1656504843224</td>
#     </tr>
#     <tr>
#       <th>last_updated_time</th>
#       <td>1656504843224</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Write datapoints to timeseries
# Tuple of datetime and value, remember time is given in UTC

import pandas as pd
from datetime import datetime

df_wind = pd.read_csv("vinddata_2022.csv")

datapoints = []

df_wind.set_index("Tid(norsk normaltid)",inplace=True)

# %%
df_wind.tail(50)
# Out:
#                       Høyeste middelvind (1 t)  Middelvind
# Tid(norsk normaltid)
# 2022-04-26 23:00:00                        4.2         3.9
# 2022-04-27 00:00:00                        5.0         4.6
# 2022-04-27 01:00:00                        5.1         4.8
# 2022-04-27 02:00:00                        4.8         4.6
# 2022-04-27 03:00:00                        4.8         3.0
# 2022-04-27 04:00:00                        3.4         3.2
# 2022-04-27 05:00:00                        4.1         4.0
# 2022-04-27 06:00:00                        4.3         2.8
# 2022-04-27 07:00:00                        5.2         5.2
# 2022-04-27 08:00:00                        5.6         5.5
# 2022-04-27 09:00:00                        6.1         4.1
# 2022-04-27 10:00:00                        5.0         4.2
# 2022-04-27 11:00:00                        4.4         3.0
# 2022-04-27 12:00:00                        3.0         0.8
# 2022-04-27 13:00:00                        1.6         1.1
# 2022-04-27 14:00:00                        2.5         1.8
# 2022-04-27 15:00:00                        2.7         2.2
# 2022-04-27 16:00:00                        2.8         1.7
# 2022-04-27 17:00:00                        2.9         1.3
# 2022-04-27 18:00:00                        2.2         0.6
# 2022-04-27 19:00:00                        3.3         3.1
# 2022-04-27 20:00:00                        3.1         1.9
# 2022-04-27 21:00:00                        2.5         2.1
# 2022-04-27 22:00:00                        2.3         0.5
# 2022-04-27 23:00:00                        1.4         1.4
# 2022-04-28 00:00:00                        2.0         0.8
# 2022-04-28 01:00:00                        1.8         1.7
# 2022-04-28 02:00:00                        2.3         0.8
# 2022-04-28 03:00:00                        2.1         1.1
# 2022-04-28 04:00:00                        2.4         2.0
# 2022-04-28 05:00:00                        1.8         1.4
# 2022-04-28 06:00:00                        2.5         0.7
# 2022-04-28 07:00:00                        2.3         0.8
# 2022-04-28 08:00:00                        2.6         1.3
# 2022-04-28 09:00:00                        2.0         2.0
# 2022-04-28 10:00:00                        2.1         2.0
# 2022-04-28 11:00:00                        3.7         3.1
# 2022-04-28 12:00:00                        4.1         3.6
# 2022-04-28 13:00:00                        3.4         2.7
# 2022-04-28 14:00:00                        3.3         2.3
# 2022-04-28 15:00:00                        3.5         3.4
# 2022-04-28 16:00:00                        3.6         2.7
# 2022-04-28 17:00:00                        2.6         1.2
# 2022-04-28 18:00:00                        4.0         3.2
# 2022-04-28 19:00:00                        3.2         2.7
# 2022-04-28 20:00:00                        3.5         3.3
# 2022-04-28 21:00:00                        3.3         2.6
# 2022-04-28 22:00:00                        3.7         3.7
# 2022-04-28 23:00:00                        4.9         4.7
# 2022-04-29 00:00:00                        5.0         4.0

# %%
for i in range(len(df_wind.index)):
    if str(df_wind.index[i])[:-6] == "2022-01-01 00:00:00" or str(df_wind.index[i])[:-6] == "2013-10-25 17:00:00":
        continue
    index = datetime.strptime(str(df_wind.index[i]), '%Y-%m-%d %H:%M:%S')
    # if df_wind.loc[str(index) + "+01:00",'wind_forecast'] != "-":
    datapoint = float(df_wind.loc[str(index),'Middelvind'])
    datatuple = (index,datapoint)
    datapoints.append(datatuple)

# print(datapoints)
# datapoints = [
#     (datetime(2022,6,20,9), 0),
#     (datetime(2022,6,20,9,58), 5),
#     (datetime(2022,6,20,10), 30),
#     (datetime(2022,6,20,10,50), 24),
#     (datetime(2022,6,20,11,50), 0),
# ]   

res = client.time_series.retrieve(external_id="NO1_wind_per_15min")
res.unit = "m/s"
# res = client.time_series.update(res)

print(client.time_series.retrieve(external_id="NO1_wind_per_15_min_test").id)

client.datapoints.insert(datapoints, id=client.time_series.retrieve(external_id="NO1_wind_per_15_min_test").id)
# Out:
# 866823001927274
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\57861\OneDrive - Hafslund Eco\Skrivebord\heco.sommer.notebooks\heco.sommer.notebooks\cdf_upload_vind.ipynb Cell 12' in <cell line: 25>()
#      <a href='vscode-notebook-cell:/c%3A/Users/57861/OneDrive%20-%20Hafslund%20Eco/Skrivebord/heco.sommer.notebooks/heco.sommer.notebooks/cdf_upload_vind.ipynb#ch0000012?line=20'>21</a> # res = client.time_series.update(res)
#      <a href='vscode-notebook-cell:/c%3A/Users/57861/OneDrive%20-%20Hafslund%20Eco/Skrivebord/heco.sommer.notebooks/heco.sommer.notebooks/cdf_upload_vind.ipynb#ch0000012?line=22'>23</a> print(client.time_series.retrieve(external_id="NO1_wind_per_15_min_test").id)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/57861/OneDrive%20-%20Hafslund%20Eco/Skrivebord/heco.sommer.notebooks/heco.sommer.notebooks/cdf_upload_vind.ipynb#ch0000012?line=24'>25</a> client.time_series.update(datapoints, id=client.time_series.retrieve(external_id="NO1_wind_per_15min").id)
#
# TypeError: update() got an unexpected keyword argument 'id'

# %%
# Get datapoints in pandas dataframe
df = client.datapoints.retrieve_dataframe(
    start=datetime(2022, 6, 20),
    end=datetime(2022, 6, 21),
    aggregates=["average", "sum"],
    granularity="1h",
    id=client.time_series.retrieve(external_id="NO1_generation_test_series_2022-05-20 12:00:00").id,
)
print(df)
# Out:
#                      2661217891469451|average  2661217891469451|sum
# 2022-06-20 09:00:00                       3.0                   5.0
# 2022-06-20 10:00:00                      27.0                  54.0
# 2022-06-20 11:00:00                       0.0                   0.0
