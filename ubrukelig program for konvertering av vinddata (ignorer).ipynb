# %%
import dateparser
import pandas as pd

df_wind = pd.DataFrame(pd.read_csv("vinddata_2022.csv"))

for i in range(len(df_wind.index)):
    print(df_wind["Tid(norsk normaltid)"].iloc[i])
    df_wind["Tid(norsk normaltid)"].iloc[i] = dateparser.parse(df_wind["Tid(norsk normaltid)"].iloc[i]).strftime("%Y-%m-%d %H:%M:%S")
# Out:
# 01.01.2022 01:00
# c:\Users\57861\.conda\envs\p39_sommer\lib\site-packages\dateparser\date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
# C:\Users\57861\AppData\Local\Temp\ipykernel_25536\2999859430.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wind["Tid(norsk normaltid)"].iloc[i] = dateparser.parse(df_wind["Tid(norsk normaltid)"].iloc[i]).strftime("%Y-%m-%d %H:%M:%S")
# 01.01.2022 02:00
# 01.01.2022 03:00
# 01.01.2022 04:00
# 01.01.2022 05:00
# 01.01.2022 06:00
# 01.01.2022 07:00
# 01.01.2022 08:00
# 01.01.2022 09:00
# ...

# %%
df_wind.to_csv("vinddata_2022.csv")
